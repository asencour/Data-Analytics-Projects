# %% [markdown]
# ### Описание проекта
#
# Сеть фитнес-центров «Культурист-датасаентист» разрабатывает стратегию взаимодействия с пользователями на основе аналитических данных.
#
# Распространённая проблема фитнес-клубов и других сервисов — отток клиентов. Как понять, что пользователь больше не с вами? Можно записать в отток тех, кто попросил закрыть договор или удалил аккаунт. Однако клиенты не всегда уходят демонстративно: чаще перестают пользоваться сервисом тихо.
#
# Индикаторы оттока зависят от специфики отрасли. Когда пользователь редко, но стабильно закупается в интернет-магазине — не похоже, что он «отвалился». А вот если две недели не заходит на канал с ежедневно обновляемым контентом, дела плохи: подписчик заскучал и, кажется, оставил вас.
#
# Для фитнес-центра можно считать, что клиент попал в отток, если за последний месяц ни разу не посетил спортзал. Конечно, не исключено, что он уехал на Бали и по приезде обязательно продолжит ходить на фитнес. Однако чаще бывает наоборот. Если клиент начал новую жизнь с понедельника, немного походил в спортзал, а потом пропал — скорее всего, он не вернётся.
# Чтобы бороться с оттоком, отдел по работе с клиентами «Культуриста-датасаентиста» перевёл в электронный вид множество анкет пользователей. Ваша задача — провести анализ и подготовить план действий по удержанию клиентов.
#
# А именно:
# - научиться прогнозировать вероятность оттока (на уровне следующего месяца) для каждого клиента;
# - сформировать типичные портреты пользователей: выделить несколько наиболее ярких групп и охарактеризовать их основные свойства;
# - проанализировать основные признаки, наиболее сильно влияющие на отток;
# - сформулировать основные выводы и разработать рекомендации по повышению качества работы с клиентами:
# 1) выделить целевые группы клиентов;
# 2) предложить меры по снижению оттока;
# 3) определить другие особенности взаимодействия с клиентами.

# %% [markdown]
# ### Описание данных
#
# Набор данных включает следующие поля:
# - 'Churn' — факт оттока в текущем месяце;
#
# Данные пользователя за предыдущий до проверки факта оттока месяц:
# - 'gender' — пол
# - 'Near_Location' — проживание или работа в районе, где находится фитнес-центр
# - 'Partner' — сотрудник компании-партнёра клуба (сотрудничество с компаниями, чьи сотрудники могут получать скидки на абонемент — в таком случае фитнес-центр хранит информацию о работодателе клиента)
# - Promo_friends — факт первоначальной записи в рамках акции «приведи друга» (использовал промо-код от знакомого при оплате первого абонемента)
# - 'Phone' — наличие контактного телефона
# - 'Age' — возраст
# - 'Lifetime' — время с момента первого обращения в фитнес-центр (в месяцах)
#
# Информация на основе журнала посещений, покупок и информация о текущем статусе абонемента клиента
# - 'Contract_period' — длительность текущего действующего абонемента (месяц, 3 месяца, 6 месяцев, год)
# - 'Month_to_end_contract' — срок до окончания текущего действующего абонемента (в месяцах)
# - 'Group_visits' — факт посещения групповых занятий
# - 'Avg_class_frequency_total' — средняя частота посещений в неделю за все время с начала действия абонемента
# - 'Avg_class_frequency_current_month' — средняя частота посещений в неделю за предыдущий месяц
# - 'Avg_additional_charges_total' — суммарная выручка от других услуг фитнес-центра: кафе, спорт-товары, косметический и массажный салон
#
# Путь к файлу: /datasets/gym_churn.csv

# %% [markdown]
# ### Схема выполнения проекта
#
# #### Шаг 1. Откройте файл с данными и изучите общую информацию
#
# #### Шаг 2. Проведите исследовательский анализ данных (EDA)
#
# - Посмотрите на датасет: есть ли в нем отсутствующие признаки, изучите средние значения и стандартные отклонения (пригодится метод describe());
# - Посмотрите на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался (воспользуйтесь методом groupby());
# - Постройте столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток);
# - Постройте матрицу корреляций и отобразите её.
#
# #### Шаг 3. Постройте модель прогнозирования оттока пользователей
#
# Постройте модель бинарной классификации пользователей, где целевой признак — факт оттока пользователя в следующем месяце:
# Разбейте данные на обучающую и валидационную выборку функцией train_test_split().
#
# Обучите модель на train-выборке любыми двумя способами:
#
# - логистической регрессией
# - случайным лесом
#
# Оцените метрики accuracy, precision и recall для обеих моделей на валидационной выборке. Сравните по ним модели. Какая модель показала себя лучше на основании метрик?
#
# #### Шаг 4. Сделайте кластеризацию пользователей
#
# - Отложите в сторону столбец с оттоком и проведите кластеризацию объектов (пользователей):
# - Стандартизируйте данные.
# - Постройте матрицу расстояний функцией linkage() на стандартизованной матрице признаков и нарисуйте дендрограмму. Внимание: отрисовка дендрограммы может занять время! На основании полученного графика предположите, какое количество кластеров можно выделить.
# - Обучите модель кластеризации на основании алгоритма K-Means и спрогнозируйте кластеры клиентов. Договоримся за число кластеров принять n=5, чтобы ваши результаты можно было сравнивать с результатами остальных студентов. Однако, конечно, в жизни никто не скажет вам правильный ответ, и решение остаётся за вами (на основании изучения графика из предыдущего пункта).
# - Посмотрите на средние значения признаков для кластеров. Можно ли сразу что-то заметить?
# - Постройте распределения признаков для кластеров. Можно ли что-то заметить по ним?
# - Для каждого полученного кластера посчитайте долю оттока (методом groupby()). Отличаются ли они по доле оттока? Какие кластеры склонны к оттоку, а какие — надёжны?
#
# #### Шаг 5. Сформулируйте выводы и сделайте базовые рекомендации по работе с клиентами

# %%
import pandas as pd
import math
import numpy as np
from scipy import stats as st
import plotly.express as px
from plotly import graph_objects as go
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from warnings import simplefilter
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import KMeans

# %%
simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ### Шаг 1. Открытие файла, общая информация

# %%
df = pd.read_csv('/datasets/gym_churn.csv')
df.head()
# Out:
#    gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# 0             1   29                     14.227470                    5.0
# 1             1   31                    113.202938                   12.0
# 2             0   28                    129.448479                    1.0
# 3             1   33                     62.669863                   12.0
# 4             0   26                    198.362265                    1.0
#
#    Lifetime  Avg_class_frequency_total  Avg_class_frequency_current_month  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
# gender                               4000 non-null int64
# Near_Location                        4000 non-null int64
# Partner                              4000 non-null int64
# Promo_friends                        4000 non-null int64
# Phone                                4000 non-null int64
# Contract_period                      4000 non-null int64
# Group_visits                         4000 non-null int64
# Age                                  4000 non-null int64
# Avg_additional_charges_total         4000 non-null float64
# Month_to_end_contract                4000 non-null float64
# Lifetime                             4000 non-null int64
# Avg_class_frequency_total            4000 non-null float64
# Avg_class_frequency_current_month    4000 non-null float64
# Churn                                4000 non-null int64
# dtypes: float64(4), int64(10)
# ...

# %% [markdown]
# ### Шаг 2. Исследовательский анализ данных

# %%
df.describe()
# Out:
#             gender  Near_Location      Partner  Promo_friends        Phone  \
# count  4000.000000    4000.000000  4000.000000    4000.000000  4000.000000
# mean      0.510250       0.845250     0.486750       0.308500     0.903500
# std       0.499957       0.361711     0.499887       0.461932     0.295313
# min       0.000000       0.000000     0.000000       0.000000     0.000000
# 25%       0.000000       1.000000     0.000000       0.000000     1.000000
# 50%       1.000000       1.000000     0.000000       0.000000     1.000000
# 75%       1.000000       1.000000     1.000000       1.000000     1.000000
# max       1.000000       1.000000     1.000000       1.000000     1.000000
#
#        Contract_period  Group_visits          Age  \
# count      4000.000000   4000.000000  4000.000000
# mean          4.681250      0.412250    29.184250
# std           4.549706      0.492301     3.258367
# min           1.000000      0.000000    18.000000
# ...

# %% [markdown]
# Справочная информация, доступная из первого взгляда на таблицу (исходя из предположения, что 1 значит "да"):
#
# - среди клиентов примерно поровну мужчин и женщин
# - 84% живут или работают поблизости от фитнес-центра
# - почти половина клиентов - сотрудники компании-партнера клуба
# - 30% клиентов пришли по приглашению друга
# - 90% оставили контактный телефон (возможно, те, кто не оставил, с большей вероятностью ушли или уйдут)
# - как правило, абонемент приобретают на полгода
# - в групповых занятиях участвуют 41% клиентов
# - средний возраст - 30 лет, нет никого младше 18 и старше 41 года
# - в среднем на допуслуги тратят 146 р в месяц
# - в среднем клиенты ходят в зал дважды в неделю
# - и чуть более полутора раз за неделю в последнем месяце
# - 26% клиентов ушли в отток за последний месяц

# %%
churn = (df
         .groupby('Churn')
         .agg('mean')
        )
churn
# Out:
#          gender  Near_Location   Partner  Promo_friends     Phone  \
# Churn
# 0      0.510037       0.873086  0.534195       0.353522  0.903709
# 1      0.510839       0.768143  0.355325       0.183789  0.902922
#
#        Contract_period  Group_visits        Age  Avg_additional_charges_total  \
# Churn
# 0             5.747193      0.464103  29.976523                    158.445715
# 1             1.728558      0.268615  26.989632                    115.082899
#
#        Month_to_end_contract  Lifetime  Avg_class_frequency_total  \
# Churn
# 0                   5.283089  4.711807                   2.024876
# 1                   1.662582  0.990575                   1.474995
#
#        Avg_class_frequency_current_month
# Churn
# 0                               2.027882
# 1                               1.044546

# %% [markdown]
# - Для тех, кто ушел, и и тех, кто остался, примерно одинаковы соотношения: гендерное и по наличию контактного телефона.
# - Логично, что среди оставшихся выше процент живущих или работающих поблизости (87 против 77).
# - Также среди оставшихся выше, причем существенно, процент пришедших по рекомендациям друзей (53 против 35).
# - Мало кто из тех, кто бросил занятия, покупал абонемент более чем на месяц. У тех, кто не ушел, средняя продолжительность абонемента - полгода.
# - Также среди оставшихся выше процент посещающих групповые занятия - почти вдвое (46 против 27).
# - Ушедшие в отток клиенты чуть моложе оставшихся - средний возраст 27 лет против 30. Вероятно, это можно объяснить тем, что у клиентов постарше жизнь устроена в большей степени и им (уже) не нужно платить, например, за учебу или ипотеку.
# - Косвенно вышесказанное объясняет и следующий факт: оставшиеся клиенты больше тратят на допуслуги, в среднем на 40 руб, то есть почти вполовину, больше.
# - Временной порог оттока, заявленный в условии, подтвержден: те, кто ушли, пользовались сервисом в среднем менее месяца.
# - Оставшиеся клиенты не снижают частоту посещений - как было в среднем дважды в неделю, так и осталось. У ушедших частота упала с полутора до одного раза в неделю.
#
# Таким образом, можно выделить несколько значимых признаков, влияющих на целевую переменную: близость работы / места жительства, участие в партнерских программах, в акции "приведи друга", длительность абонемента, участие в групповых занятиях, частота посещений, расходы на допуслуги и в меньшей степени - возраст.

# %%
churn = df[df['Churn'] == 1]
active = df[df['Churn'] == 0]

# %%
for col in churn.drop('Churn', axis = 1).columns:
    churn[col].plot(kind = 'hist', density = True, stacked = True, title = col)
    plt.show()

# %% [markdown]
# На графиках распределения для тех, кто ушел, более наглядно продемонстрированы выводы, полученные в предыдущих ячейках. Так, наглядно видно, что большинство клиентов из группы оттока приобрели абонементы только на 1 месяц. Распределение по возрасту похоже на нормальное вокруг возраста в 27,5 лет. Средняя частота посещений в неделю также распределена нормально вокруг значения в 1,5. Частота посещений за последний месяц и расходы на допуслуги выглядят как нормальное распределение, сильно скошенное вправо.

# %%
for col in active.drop('Churn', axis = 1).columns:
    active[col].plot(kind = 'hist', density = True, stacked = True, title = col)
    plt.show()

# %% [markdown]
# Для той части клиентов, что не попала в отток (а их почти три четверти от общего числа) распределения несколько отличаются. Так, у этих клиентов действительно существенно выше доли тех, кто купил абонемент на срок 6 или 12 месяцев, однако доля одномесячных абонементов по-прежнему самая большая. В возрастном распределении обнаруживается похожий на выброс возраст 31-32 года, а суммарная выручка от других услуг не так сильно скошена вправо.

# %%
for col in df.drop('Churn', axis = 1).columns:
    df[df['Churn'] == 1][col].plot(kind = 'hist', density = True, stacked = True, title = col, color='#92c6ff')
    df[df['Churn'] == 0][col].plot(kind = 'hist', density = True, stacked = True, title = col, color='#97F0AA', alpha=0.7)
    plt.legend(['Отток', 'Оставшиеся'], prop={'size':8})
    plt.show()

# %% [markdown]
# Здесь те же графики, что выше, только с наложением друг на друга - так нагляднее.

# %%
cm = df.corr()
fig, ax = plt.subplots(figsize=(15,15)) 
sns.heatmap(cm, annot = True, square=True, cmap="YlGnBu", ax=ax)

# %% [markdown]
# Очень сильно коррелируют между собой следующие признаки: длительность абонемента / число месяцев до окончания абонемента и средние траты на допуслуги вообще / в последнем месяце. А вот с целевой переменной у всех признаков отрицательная корреляция. Но это, вероятно, объяснимо тем, что у нее может быть всего два значения.

# %% [markdown]
# ### Шаг 3. Модель прогнозирования оттока пользователей

# %% [markdown]
# Так как целевая переменная - бинарная величина (принимает значения 0 или 1), то нужен алгоритм для решения задачи бинарной классификации - логистическая регрессия.

# %%
X = df.drop('Churn', axis = 1)
y = df['Churn']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_train_st = scaler.transform(X_train)
X_test_st = scaler.transform(X_test)

# %%
model_log = LogisticRegression(random_state=0)
model_log.fit(X_train_st, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=0, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
rf_model = RandomForestClassifier(n_estimators = 100, random_state=0)
rf_model.fit(X_train_st, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
predictions_log = model_log.predict(X_test_st)
predictions_rf = rf_model.predict(X_test_st)

# %%
print('Accuracy_log: {:.2f}'.format(accuracy_score(y_test, predictions_log)))
print('Precision_log: {:.2f}'.format(precision_score(y_test, predictions_log)))
print('Recall_log: {:.2f}'.format(recall_score(y_test, predictions_log)))
# Out:
# Accuracy_log: 0.92
# Precision_log: 0.85
# Recall_log: 0.83

# %%
print('Accuracy_rf: {:.2f}'.format(accuracy_score(y_test, predictions_rf)))
print('Precision_rf: {:.2f}'.format(precision_score(y_test, predictions_rf)))
print('Recall_rf: {:.2f}'.format(recall_score(y_test, predictions_rf)))
# Out:
# Accuracy_rf: 0.92
# Precision_rf: 0.84
# Recall_rf: 0.81

# %% [markdown]
# Модель логистической регрессии показала себя лучше, чем модель случайного леса, если судить по метрикам. Доля правильных ответов одинакова - 92%, а вот по точности и полноте случайный лес немного, но уступает логистической регрессии.

# %% [markdown]
# ### Шаг 4. Кластеризация пользователей

# %%
df_cluster = X
df_cluster.head()
# Out:
#    gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# 0             1   29                     14.227470                    5.0
# 1             1   31                    113.202938                   12.0
# 2             0   28                    129.448479                    1.0
# 3             1   33                     62.669863                   12.0
# 4             0   26                    198.362265                    1.0
#
#    Lifetime  Avg_class_frequency_total  Avg_class_frequency_current_month
# ...

# %%
x_sc = scaler.fit_transform(df_cluster)
print(x_sc[:5])
# Out:
# [[ 0.97970588  0.42788074  1.02686062  1.49716101 -3.05985201  0.28989014
#    1.19403206 -0.0565538  -1.37753121  0.16160501 -0.19332863 -1.91191971
#   -1.67847198]
#  [-1.0207145   0.42788074 -0.973842   -0.66793083  0.32681319  1.60882159
#    1.19403206  0.55732732 -0.35021325  1.83194105  0.87368001  0.04517569
#    0.1360137 ]
#  [-1.0207145   0.42788074  1.02686062 -0.66793083  0.32681319 -0.8092194
#   -0.83749845 -0.36349436 -0.1815923  -0.79287273 -0.46008079 -0.02049263
#   -0.02901851]
#  [-1.0207145   0.42788074  1.02686062  1.49716101  0.32681319  1.60882159
#    1.19403206  1.17120844 -0.87472237  1.83194105 -0.46008079  1.36465509
#    1.51045005]
#  [ 0.97970588  0.42788074  1.02686062  1.49716101  0.32681319 -0.8092194
#   -0.83749845 -0.97737548  0.5336998  -0.79287273 -0.19332863 -0.78707638
#   -0.61454183]]

# %%
linked = linkage(x_sc, method = 'ward')

# %%
plt.figure(figsize=(15, 10))  
dendrogram(linked, orientation='top')
plt.title('Hierarchial clustering for fitness')
plt.show()

# %% [markdown]
# Предложенное оптимальное число кластеров - 4, это число разных цветов на графике. В задании указано число кластеров 5, поэтому кластеризировать с помощью алгоритма К-Means будем по пяти кластерам

# %%
km = KMeans(n_clusters = 5, random_state=0) 
labels = km.fit_predict(x_sc)

# %%
df['cluster_km'] = labels

# %%
(df
 .groupby('cluster_km')
 .agg('mean')
)
# Out:
#               gender  Near_Location   Partner  Promo_friends     Phone  \
# cluster_km
# 0           0.502473       0.959446  0.783383       0.574679  1.000000
# 1           0.522078       0.862338  0.470130       0.306494  0.000000
# 2           0.495050       0.000000  0.463366       0.079208  1.000000
# 3           0.485737       1.000000  0.350238       0.240095  1.000000
# 4           0.560335       0.976105  0.356033       0.229391  0.998805
#
#             Contract_period  Group_visits        Age  \
# cluster_km
# 0                 10.884273      0.543027  29.980218
# 1                  4.787013      0.425974  29.301299
# 2                  2.352475      0.215842  28.477228
# 3                  1.948494      0.341521  28.167987
# 4                  2.665472      0.473118  30.127838
#
#             Avg_additional_charges_total  Month_to_end_contract  Lifetime  \
# cluster_km
# 0                             160.706969               9.950544  4.738872
# ...

# %% [markdown]
# Глядя на средние значения признаков по кластерам, можно заметить:
# - Кластер 0 - самый устойчивый. Его представители в 96% случаев живут или работают рядом с клубом, в 78% случаев пользуются партнерскими программами, в 57% случаев пришли по приглашению друзей. У представителей этого кластера самые длинные абонементы (почти 11 месяцев в среднем, то есть большинство берет годовые абонементы), они чаще других ходят на групповые занятия, этот кластер на втором месте по средним тратам на допуслуги и частоте посещений, из него в отток ушли только 2% клиентов.
# - Кластер 4 - второй по устойчивости. Здесь еще большая доля клиентов живет или работает поблизости, этот кластер больше всех тратит на допуслуги и чаще всех посещает зал - в среднем почти трижды в неделю. А вот средний абонемент - чуть менее трех месяцев: значит, представители этого кластера берут абонемент максимум на полгода. В отток ушли всего 7% представителей кластера.
# - Самые неустойчивые - кластеры 2 и 3. В кластере 2 нет никого, кто бы жил или работал рядом с залом и всего 7% пришли по приглашению друга. Кластер 3 меньше всех тратит на допуслуги (и он же самый юный), а также реже всех посещает зал - в среднем раз в неделю. Из кластера 2 в отток ушли 44%, из кластера 3 - больше половины.

# %%
df.head()
# Out:
#    gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# 0             1   29                     14.227470                    5.0
# 1             1   31                    113.202938                   12.0
# 2             0   28                    129.448479                    1.0
# 3             1   33                     62.669863                   12.0
# 4             0   26                    198.362265                    1.0
#
#    Lifetime  Avg_class_frequency_total  Avg_class_frequency_current_month  \
# ...

# %% [markdown]
# Часть признаков - бинарные, часть - непрерывные либо дискретные, но с более чем двумя значениями. Эти две группы лучше разделить.

# %%
df_binary = df[['gender', 'Near_Location', 'Partner', 'Promo_friends', 'Phone', 'Group_visits', 'Churn']]
df_non_binary = df[['Contract_period', 'Age', 'Avg_additional_charges_total', 'Month_to_end_contract', 'Lifetime', 'Avg_class_frequency_total', 'Avg_class_frequency_current_month']]

# %%
plt.figure(figsize=(13, 15))
sns.set(style="whitegrid")
for i in range(len(df_binary.columns)):
    plt.subplot(3, 3, i+1)
    x = df['cluster_km']
    y = df_binary.iloc[:,i]
    sns.barplot(x=x, y=y, ci = None)
plt.tight_layout()
plt.show()

# %% [markdown]
# - Во-первых, получили графическую визуализацию склонности к оттоку. Кластеры 2 и 3 наиболее склонны, кластеры 0 и 4 - наименее склонны к оттоку.
# - Гендерное равенство нарушено только в кластере 4, но вряд ли это является существенным признаком.
# - Партнерскими программами кластеры 1 и 2 пользуются активнее, чем кластер 4, но они менее устойчивы. Это говорит о том, что личная мотивация тоже важна. Тем не менее самый неустойчивый - кластер 3 - пользуется партнерками менее всех.
# - Акция "Приведи друга" тоже срабатывает схожим образом: кластер с самой большой долей ее использования - 1-й - это самый устойчивый кластер, а с наименьшей долей - наименее устойчивый. Но внутри распределения видно, что второй по устойчивости кластер 4 находится на предпоследнем месте по доле использования этой акции.
# - Указание контактного номера не является по-настоящему важным признаком.
# - А вот групповые посещения действительно важны: кластеры, которые участвуют в них чаще всего - это и самые устойчивые кластеры (0 и 4).

# %%
plt.figure(figsize=(13,15))
for i in range(len(df_non_binary.columns)):
    plt.subplot(3,3,i+1)
    x = df['cluster_km']
    y = df_non_binary.iloc[:,i]
    sns.boxplot(x=x, y=y, data=df)
plt.tight_layout()

# %%
plt.figure(figsize = (13,15))
i=0
for col in df_non_binary.columns:
    plt.subplot(3, 3, i+1)
    for x in range(0, 5):
        sns.distplot(df.query('cluster_km == @x')[col],
                    hist=False,
                    rug=True,
                    kde_kws={'label': 'Кластер '+ str(x)})
    i+=1
plt.tight_layout()

# %% [markdown]
# Распределение срока абонемента по кластерам не слишком информативно, но эта зависимость лучше проиллюстрирована в таблице выше. Все остальные распределения по всем кластерам похожи на нормальные со средним в разных точках, за исключением признака "Число месяцев до конца абонемента". Что объяснимо, так как срок абонемента может принимать лишь три дискретных значения.

# %% [markdown]
# ### Шаг 5. Выводы и рекомендации
#
# #### Общие выводы
#
# - среди клиентов примерно поровну мужчин и женщин
# - 84% живут или работают поблизости от фитнес-центра
# - почти половина клиентов - сотрудники компании-партнера клуба
# - 30% клиентов пришли по приглашению друга
# - 90% оставили контактный телефон (возможно, те, кто не оставил, с большей вероятностью ушли или уйдут)
# - как правило, абонемент приобретают на полгода
# - в групповых занятиях участвуют 41% клиентов
# - средний возраст - 30 лет, нет никого младше 18 и старше 41 года
# - в среднем на допуслуги тратят 146 р в месяц
# - в среднем клиенты ходят в зал дважды в неделю
# - и чуть более полутора раз за неделю в последнем месяце
# - 26% клиентов ушли в отток за последний месяц
# - Для тех, кто ушел, и и тех, кто остался, примерно одинаковы соотношения: гендерное и по наличию контактного телефона.
# - Логично, что среди оставшихся выше процент живущих или работающих поблизости (87 против 77).
# - Также среди оставшихся выше, причем существенно, процент пришедших по рекомендациям друзей (53 против 35).
# - Мало кто из тех, кто бросил занятия, покупал абонемент более чем на месяц. У тех, кто не ушел, средняя продолжительность абонемента - полгода.
# - Также среди оставшихся выше процент посещающих групповые занятия - почти вдвое (46 против 27).
# - Ушедшие в отток клиенты чуть моложе оставшихся - средний возраст 27 лет против 30. Вероятно, это можно объяснить тем, что у клиентов постарше жизнь устроена в большей степени и им (уже) не нужно платить, например, за учебу или ипотеку.
# - Косвенно вышесказанное объясняет и следующий факт: оставшиеся клиенты больше тратят на допуслуги, в среднем на 40 руб, то есть почти вполовину, больше.
# - Временной порог оттока, заявленный в условии, подтвержден: те, кто ушли, пользовались сервисом в среднем менее месяца.
# - Оставшиеся клиенты не снижают частоту посещений - как было в среднем дважды в неделю, так и осталось. У ушедших частота упала с полутора до одного раза в неделю.
# - Таким образом, можно выделить несколько значимых признаков, влияющих на целевую переменную: близость работы / места жительства, участие в партнерских программах, в акции "приведи друга", длительность абонемента, участие в групповых занятиях, частота посещений, расходы на допуслуги и в меньшей степени - возраст.
#
# #### Выводы по итогам кластеризации
# - В качестве наиболее важных признаков, влияющих на склонность к оттоку, можно выделить: патнерские программы и акции для друзей; групповые занятия; срок абонемента; траты на допуслуги; lifetime; частота посещений.
# - Однако закономерности и в других признаках подсказывают возможные стратегии взаиможействия с пользователями. К примеру, очевидно, что чем младше клиент, тем вероятнее, что он быстро уйдет в отток.
# - С учетом вышесказанного стоит обратить внимание на молодых посетителей. Это могут быть акции для студентов, например, или скидки на парные абонементы.
# - Хорошо работают партнерские программы и акции для друзей, эти направления не стоит бросать, а лучше развивать.
# - Также хорошо работают групповые занятия, на этом тоже можно сделать акцент.
# - География также имеет существенное значение, так что важно привлекать тех, кто живет или работает рядом.
# - Также стоит простимулировать частоту посещений. К примеру, тем, кто пришел минимум 8 раз в месяц, ставить, допустим, печать в сертификат посещений. В том, что касается фитнеса, очень важно подкрепление действия результатом. Многие бросают, не увидев за первый месяц существенных изменений в себе. Поэтому даже нематериальные подкрепления, простые ачивки могут хорошо сработать на мотивацию и, как следствие, на удержание клиента.
